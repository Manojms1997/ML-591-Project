# %%
from google.colab import drive
drive.mount('/content/drive')


import tensorflow as tf 
import numpy as np

input_shape = (224,224,3)
classes = 2
classifier_activation='softmax'
learning_rate = 0.0001
batch_size = 16
epochs = 70 
DESTINATION = ""

train_image_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_train_images.npy"   
train_labels_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_train_labels.npy"   
test_image_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_test_images.npy"
test_labels_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_test_labels.npy"
x_train = np.load(train_image_path)
y_train = np.load(train_labels_path)
x_test = np.load(test_image_path)
y_test = np.load(test_labels_path)

base_model = tf.keras.applications.InceptionResNetV2(weights = None, include_top = False, input_shape = input_shape)
x = base_model.output         
x = tf.keras.layers.GlobalAveragePooling2D()(x)
output = tf.keras.layers.Dense(classes, activation=classifier_activation)(x)

model = tf.keras.Model(inputs = base_model.input, outputs = output)

optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

model.compile(optimizer = optimizer,
                loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics = ['accuracy'])
    
results = model.fit(x_train, y_train, epochs = epochs,
                    validation_data = (x_test, y_test), 
                    batch_size=batch_size, 
                    callbacks = None
                    )

#losses = pd.DataFrame(model.history.history)
#losses[['loss','val_loss']].plot()

save_model = "model/inceptionModel.h5"
model.save(save_model)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/70
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 39/39 [==============================] - 40s 501ms/step - loss: 0.2499 - accuracy: 0.9302 - val_loss: 0.7124 - val_accuracy: 0.8058
# Epoch 2/70
# 39/39 [==============================] - 14s 360ms/step - loss: 0.0792 - accuracy: 0.9838 - val_loss: 1.2355 - val_accuracy: 0.8058
# Epoch 3/70
# 39/39 [==============================] - 14s 363ms/step - loss: 0.0413 - accuracy: 0.9919 - val_loss: 1.5511 - val_accuracy: 0.8058
# Epoch 4/70
# ...

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
new_model = tf.keras.models.load_model('/content/model/inceptionModel.h5')

# %%
loss, acc = new_model.evaluate(x_test, y_test, verbose=2)
print('Testing saved model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 9/9 - 2s - loss: 0.0591 - accuracy: 0.9892 - 2s/epoch - 181ms/step
# Testing saved model, accuracy: 98.92%

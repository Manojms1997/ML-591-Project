# %%
from google.colab import drive
drive.mount('/content/drive')


import tensorflow as tf 
import numpy as np

input_shape = (224,224,3)
classes = 2
classifier_activation='softmax'
learning_rate = 0.0001
batch_size = 16
epochs = 70 
DESTINATION = ""

train_image_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_train_images.npy"   
train_labels_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_train_labels.npy"   
test_image_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_test_images.npy"
test_labels_path = DESTINATION + "/content/drive/MyDrive/DATA/OUTPUT_DIR/New_test_labels.npy"
x_train = np.load(train_image_path)
y_train = np.load(train_labels_path)
x_test = np.load(test_image_path)
y_test = np.load(test_labels_path)

base_model = tf.keras.applications.InceptionResNetV2(weights = None, include_top = False, input_shape = input_shape)
x = base_model.output         
x = tf.keras.layers.GlobalAveragePooling2D()(x)
output = tf.keras.layers.Dense(classes, activation=classifier_activation)(x)

model = tf.keras.Model(inputs = base_model.input, outputs = output)

optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

model.compile(optimizer = optimizer,
                loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics = ['accuracy'])
    
results = model.fit(x_train, y_train, epochs = epochs,
                    validation_data = (x_test, y_test), 
                    batch_size=batch_size, 
                    callbacks = None
                    )

#losses = pd.DataFrame(model.history.history)
#losses[['loss','val_loss']].plot()

save_model = "inceptionModel.h5"
model.save(save_model)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/70
# 39/39 [==============================] - 34s 452ms/step - loss: 0.1878 - accuracy: 0.9351 - val_loss: 0.5763 - val_accuracy: 0.8058
# Epoch 2/70
# 39/39 [==============================] - 15s 398ms/step - loss: 0.1023 - accuracy: 0.9708 - val_loss: 1.1014 - val_accuracy: 0.8058
# Epoch 3/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0664 - accuracy: 0.9708 - val_loss: 1.7098 - val_accuracy: 0.8058
# Epoch 4/70
# 39/39 [==============================] - 15s 390ms/step - loss: 0.0351 - accuracy: 0.9854 - val_loss: 2.3381 - val_accuracy: 0.8058
# Epoch 5/70
# 39/39 [==============================] - 14s 371ms/step - loss: 0.0849 - accuracy: 0.9692 - val_loss: 2.8667 - val_accuracy: 0.8058
# Epoch 6/70
# 39/39 [==============================] - 14s 369ms/step - loss: 0.0399 - accuracy: 0.9903 - val_loss: 1.7633 - val_accuracy: 0.8058
# Epoch 7/70
# 39/39 [==============================] - 14s 370ms/step - loss: 0.0121 - accuracy: 0.9984 - val_loss: 2.1865 - val_accuracy: 0.8058
# Epoch 8/70
# 39/39 [==============================] - 15s 393ms/step - loss: 0.0096 - accuracy: 0.9984 - val_loss: 2.3536 - val_accuracy: 0.8058
# Epoch 9/70
# 39/39 [==============================] - 14s 370ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.0376 - val_accuracy: 0.8058
# Epoch 10/70
# 39/39 [==============================] - 14s 370ms/step - loss: 7.8716e-04 - accuracy: 1.0000 - val_loss: 1.5748 - val_accuracy: 0.8058
# Epoch 11/70
# 39/39 [==============================] - 15s 393ms/step - loss: 0.0623 - accuracy: 0.9886 - val_loss: 1.0207 - val_accuracy: 0.8058
# Epoch 12/70
# 39/39 [==============================] - 14s 369ms/step - loss: 0.0128 - accuracy: 0.9984 - val_loss: 0.0486 - val_accuracy: 0.9928
# Epoch 13/70
# 39/39 [==============================] - 14s 370ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0563 - val_accuracy: 0.9676
# Epoch 14/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.2528 - val_accuracy: 0.8921
# Epoch 15/70
# 39/39 [==============================] - 15s 390ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0684 - val_accuracy: 0.9604
# Epoch 16/70
# 39/39 [==============================] - 15s 390ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9892
# Epoch 17/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.0153 - val_accuracy: 0.9964
# Epoch 18/70
# 39/39 [==============================] - 14s 371ms/step - loss: 0.0190 - accuracy: 0.9968 - val_loss: 0.0987 - val_accuracy: 0.9460
# Epoch 19/70
# 39/39 [==============================] - 15s 392ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9892
# Epoch 20/70
# 39/39 [==============================] - 14s 373ms/step - loss: 6.7262e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9928
# Epoch 21/70
# 39/39 [==============================] - 15s 390ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9892
# Epoch 22/70
# 39/39 [==============================] - 15s 389ms/step - loss: 6.4694e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9964
# Epoch 23/70
# 39/39 [==============================] - 15s 373ms/step - loss: 4.8366e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9964
# Epoch 24/70
# 39/39 [==============================] - 15s 391ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9892
# Epoch 25/70
# 39/39 [==============================] - 15s 391ms/step - loss: 9.1056e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9892
# Epoch 26/70
# 39/39 [==============================] - 14s 371ms/step - loss: 3.7199e-04 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9892
# Epoch 27/70
# 39/39 [==============================] - 15s 374ms/step - loss: 1.7340e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9892
# Epoch 28/70
# 39/39 [==============================] - 15s 390ms/step - loss: 1.6371e-04 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9892
# Epoch 29/70
# 39/39 [==============================] - 15s 391ms/step - loss: 4.6759e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9892
# Epoch 30/70
# 39/39 [==============================] - 15s 391ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.
ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9892
# Epoch 52/70
# 39/39 [==============================] - 15s 393ms/step - loss: 6.3284e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9964
# Epoch 53/70
# 39/39 [==============================] - 14s 371ms/step - loss: 1.6454e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9964
# Epoch 54/70
# 39/39 [==============================] - 15s 390ms/step - loss: 1.5593e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9964
# Epoch 55/70
# 39/39 [==============================] - 15s 373ms/step - loss: 0.0122 - accuracy: 0.9951 - val_loss: 0.0139 - val_accuracy: 0.9964
# Epoch 56/70
# 39/39 [==============================] - 14s 371ms/step - loss: 0.0881 - accuracy: 0.9708 - val_loss: 9.8612 - val_accuracy: 0.2806
# Epoch 57/70
# 39/39 [==============================] - 14s 371ms/step - loss: 0.0174 - accuracy: 0.9919 - val_loss: 5.5044 - val_accuracy: 0.3741
# Epoch 58/70
# 39/39 [==============================] - 14s 372ms/step - loss: 0.0169 - accuracy: 0.9968 - val_loss: 0.5674 - val_accuracy: 0.9281
# Epoch 59/70
# 39/39 [==============================] - 14s 370ms/step - loss: 0.0155 - accuracy: 0.9968 - val_loss: 0.0163 - val_accuracy: 0.9964
# Epoch 60/70
# 39/39 [==============================] - 15s 391ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 61/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0235 - val_accuracy: 0.9892
# Epoch 62/70
# 39/39 [==============================] - 15s 390ms/step - loss: 0.0235 - accuracy: 0.9886 - val_loss: 0.0477 - val_accuracy: 0.9820
# Epoch 63/70
# 39/39 [==============================] - 14s 371ms/step - loss: 7.6888e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 64/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.0535 - val_accuracy: 0.9856
# Epoch 65/70
# 39/39 [==============================] - 14s 370ms/step - loss: 5.6229e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9928
# Epoch 66/70
# 39/39 [==============================] - 15s 391ms/step - loss: 4.1465e-04 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9928
# Epoch 67/70
# 39/39 [==============================] - 15s 392ms/step - loss: 4.9319e-04 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9928
# Epoch 68/70
# 39/39 [==============================] - 14s 371ms/step - loss: 5.2390e-04 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9892
# Epoch 69/70
# 39/39 [==============================] - 15s 391ms/step - loss: 4.9299e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9856
# Epoch 70/70
# 39/39 [==============================] - 14s 373ms/step - loss: 0.0442 - accuracy: 0.9886 - val_loss: 0.0186 - val_accuracy: 0.9964
